# %% [markdown]
# <a href="https://colab.research.google.com/github/jonofficial/Resources/blob/main/JavaScript-notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# what is javascript? -> a web-based programming langauge which adds interactive behaviour to webpages
# js can be written on console of webbrowser or in an js environment(node)
# Node.js was invented in 2009 so that js can be run outside of browser. VScode has its own node extension so as to provide an external enviroment for js
# ctrl+k -> used to clear console

# there are 3 ways to link JS to HTML - inline,internal and external
# inline: <body onload="alert('hello');"> -> onload="js" (not a good practice)
# internal: <script type="text/javascript"> //script logic </script> is used inside head or body tag of HTML
# external: <script src="index.js"></script> is used inside head or body tag of HTML (idealy inside body tag)
# making JS in a seperate file is prefered since it promotes - code readability, modular, browser caching

# console.log() -> print function (by default creates a new line)
# window.alert() -> alert box pops up
# // -> single line comment , /* ... */ -> multi line comment
# declaration of variable -> var,let,const
# null, undefined -> special data-types

# using let rather than var is a good practice due to variable scope
# var: variable can be re-declared and updated. A global scope variable
# let: variable cannot be re-declared but can be updated. A block scope variable
# const: variable cannot be re-declared or updated. A block scope variable
# var created a lot of confusion due to re-declarability, so in 2015 new js rules(ES6-ecmascript6) were created -> let,const
# Variables declared by let are only available inside the block where they're defined, while variables declared by var are available throughout the function in which they're declared.
function foo() {
  if (true) {
    var x=1;
    let y = 2;
  }
  console.log(x); # 1
  console.log(y); # ReferenceError: y is not defined
}
foo();

# blocks -> lines of code independent of each other
# for eg:
{
    let a=5;
    console.log(a);
}
                                  -> no error since both the a are in different blocks. so output are 5 and 10 (but if inside same block-> then error pops since let doesnt)
{                                                                                                                allow re-declaration
    let a=10;
    console.log(a);
}

# there is no boolean datatype, we directly write true or false. for eg: let student=false/true;
# variable naming rules -> only letters,digits, underscore(_), $ allowed
# a digit cannot be first letter of a variable name
# reserved words cannot be variable names

# we can add numbers with string. for eg: age="21", console.log(age+1) -> 211  (the number is converted into string and then added -. called type coercion)
# for eg: 'hello'+'world'= 'helloworld'
#         'hello'+3='hello3' (automated type convertion from int to string)
# document.getElementById("p1").innerHTML="hello" -> used to access HTML elements with IDs (<p id="p1"></p>)
# operator precedence -> parenthesis() > exponents > *,/ > +,-
# \' -> escape character and counted as single character
# for eg: console.log('I'm learning') -> gives error
# so we use "I'm learning" or "I\'m learning"
# \" , \n -> other escape characters

# there are 7 primitve datatypes- number, string, boolean, undefined, null, bigint, symbol
# non-primitive includes objects(arrays, functions) etc
# typeof -> used to find datatype
# there is difference between null and undefined -> the former is a special value that can be explicity assigned to a variable and the latter
#                                                   is assigned to a variable if user didnt assign a value to variable. for eg: let x; -> typeof x gives 'undefined'
# NOTE: x=null; typeof x gives 'object' datatype but still we consider null as a primitive datatype
# null means absence of an object
# objects are collection of variables
const student={
    fullname : "rahul",                (key: value)
    age: 20,                           -> student is an object
    cgpa: 8,                               typeof student -> 'object'
    isPass: true
}

# we can access any variable's value using its key -> console.log(student["age"]) gives 20
# we can also update its values despite it being a const object

# increment/decrement has two types - post and pre
# for eg: let a=5;
          # console.log(a++);  -> gives 5 (first a is printed and then incremented)
          # console.log(++a);  -> gives 6 (first a is incremented and then printed)
# a**=4 // a=a**4 (exponent)

# difference between "==" and "==="
# let a=5;
# let b="5";
# console.log(a==b) -> gives true since "==" checks only the data and not the type(for this purpose b is converted to a integer and then compared)
# console.log(a===b) -> gives false since it checks both data and the type

# condition? true output: false output -> if condition is satisfied then true output else false output
# for eg: let age=25;
#         let result= age>18? "adult":"not adult";
#         console.log(result) -> gives adult

# switch statement -> similar to C
switch(variable){
    case  1:
      statement;
      break;
    case 2:
      statement;
      break;
}

# for,while loops -> exactly like C
 let student={
    fullname : "rahul",
    age: 20,
    cgpa: 8,
    isPass: true
}

for(let i in student){
   console.log(i, student[i]); -> key,value pair printed
}

# str.length -> similar to len(string)
# str.toUpperCase(), str.toLowerCase(), str.trim() [removes white space]
# str.slice(start,end) ->prints everything except the end index position
# str.concat(str2)
# str.replace(searchVal,newVal) -> replaces only one time
# str.replaceAll(searchVal,newVal) -> replaces every searchVal with newVal
# str.charAt(idx)
# str[0],str[1] -> string indicing
# Template strings are a feature in programming languages that allows for the embedding of expressions within string literals.
# Template strings are enclosed in backticks (the key near 1) and use ${expression} as a placeholder for evaluated expressions.
# for eg:
const name = "John";
const age = 30;

# // Using template string
const message = `Hello, my name is ${name} and I am ${age} years old.`;
console.log(message);    -> Hello, my name is John and I am 30 years old.

# The above is same as console.log("hello, my name is "+ name + " and i am "+age+" years old")

# ARRAYS - similar to objects but more easily codeable and readable (type of array is 'object')
# let heroes=["ironman","hulk","batman"];
# let info-["rahul",86,"delhi"]

# if object is used then it is tedious to write code
# for eg: let marks={
#     stud 1: 90;
#     stud 2: 78;
# }

# NOTE: Strings are immutable but arrays are mutable in all langauges
# for eg:
  str="hello";
  str[0]="y";
  console.log(str) gives hello and not yello since you can only access but cannote change the character's value
for (let i=0;i<heroes.length;i++){
    console.log(heroes[i]);
}

# (OR)
for (let i of heroes){
    console.log(i);
}

# push(): add to end
# pop(): delete from end and return
# toString(): converts array to string
# concat(): concatenates multiple arrays
# unshift(): adds element to the beginning
# shift(): delete element from start and return
# Slice(start index,end index): returns a piece of array
# Splice(start index, delcount, newEl1..): change original array(add,remove,replace) -> you can leave the replace part

# let arr=[97,95,83,85];
# console.log(arr.toString()); -> gives '97,95,83,85'
# arr.push(4) -> [97,95,83,85];
# x= arr.pop(); console.log(x) -> x=4 (pop can only be used by assigning a variable since it returns a value)

# let output=arr1.Concat(arr2,arr3,arr4...); -> concatenated arrays are stored in output

# let arr=[1,2,3,4,5,6,7];
# arr.splice(2,0,101); -> deleting nothing(since we are deleting 0 from 2nd index onwards) and adding element 101 after index 2 i.e after element 3 (adding)
# arr.splice(3,1) -> 4 gets deleted i.e deleting element at index 3 and deleting 1 element from 3 onwards (deleting)
# arr.splice(3,1,101); -> delete one element from index 3 and then replace it with 101 (replacing)

# but if we give arr.splice(4): ->gives [1,2,3,4] . if we dont mention the number of elements to be deleted from that index then it deletes all elements till end
# arr.splice() -> if no arguments are passed, then nothing is affected

# function definition
# function functionName(param1,param2){
#     //do some work;
# }

# function call -> functionName();

# arrow function -> definition of a function is stored in a variable (part of modern JS) -> such a variable is called function variable
# const arrowSum =(a,b) =>{
#     console.log(a+b);
# };
# arrowSum(3,4) -> gives 7

# the same arrowSum variable can also be used to store any other value when datatype changes to let

# NOTE: we use 'in' operator in python while we use 'includes' in JS
# for eg: -> to count the number of vowels
function count(s) {
    let c = 0;
    vowels = ["a", "e", "i", "o", "u"];
    for (let i = 0; i < s.length; i++) {
        if (vowels.includes(s[i])) {
            c++;
        }
    }
    console.log(c);
}

count("karthick"); -> gives output as 2

# speciality of JS is that u can pass a function as an argument to another function
# a callback is a function which is passed to another function as argument

# foreach
# The forEach function is a method in many programming languages that allows you to iterate over each element in a collection, such as an array or a list, and perform a specified operation on each element. The purpose is to apply a given function or code block to each item in the collection.
let arr=[1,2,3,4,5];
arr.forEach(function printVal(val) { //value at each idx
    console.log(val);
})
# the forEach puts each element of arr as val inside of the printVal()

# in terms of arrow function
arr.forEach((val)=>{
    console.log(val);
})

let arr=["pune","delhi","mumbai"];               PUNE 0
arr.forEach((val,idx)=>{                 ->      DELHI 1
    console.log(val.toUpperCase(),idx);          MUMBAI 2
})

# NOTE: forEach method is only used for arrays and not for strings
# arr.forEach(callBackFunction)

# higher order function/methods are those which either take a function as a parameter or return another function

# Q write a function using forEach to print the square of each element in array
arr=[1,2,3,4,5];
arr.forEach((i)=>{
    console.log(i**2);
})

# (OR)
let sqr=(num)=>{
    console.log(num*num);
}
arr.forEach(sqr);  -> arr.forEach(callbackFunction);

# Map- creates a new array with the results of some operation. the value its callback returns are used to form new array
# for eg:
let nums=[1,2,3];
let newarr=nums.map((val)=>{
    return val*val;                     NOTE: nums array remains unaffected since map is used to create another array
})
console.log(newarr) -> [1,4,9]

# Filter - creates a new array of elements that give true for a condition/filter
# for eg: all even numbers
let newarr=arr.filter((val)=>{
    return val%2==0;                   -> return condition (if condition is true, then val gets stored in newarr)
})

# Reduce -> performs some operations and reduces the array to a single value. it returns that single value
let numbers = [1, 2, 3, 4, 5];
let sum = numbers.reduce(function (accumulator, currentValue) {
    return accumulator + currentValue;                                      -> the accumulator is initially the first value of array, and current value keeps getting added to acc
}, 0);
console.log(sum);

# %%
# DOMS - Document object model
# everye element has properties (innerHTML, style, firstchild) and methods (click(),appendChild(),setAttribute())
# setattribute and getattribute simply differs by whether we assign any value to the element or not.
# for eg: car.colour; -> get
# car.colour=green; -> set
# Window Object - the window object represents an open window in a browser. it is browser's object(not JS's) and is autmoatically created by browser
# it is a global object with lots of properties and methods
# if you try to print window or type window directly in the console, u can get detailed description of the methods it contains
# for eg: console.log() is also a method of window (so window.console.log() also gives the output)
# typing window.document or document in console gives the whole HTML document
# console.dir(window.document) -> gives all details about the HTML document (like URL,nodes,attributes)
# dir is used to print object, while log cannot be used for that purpose (if you are writing code on JS file, but it can also be directly accessed by typing windows.document directly in console)
# when a web page is loaded, the browser creates a DOM of the page
                        #       window
                        #          |
                        #       document
                        #          |                      here if body is parent
                        #         HTML                       then div, script are children
                        #         /\                         and div and script are siblings to each other
                        #        /  \                        div -> first child    body.children[0]
                        #     head   body                    script -> last child  body.children[1]
                        #     /|\      | \
                        #    / | link  |  \
                        # meta title  div  script
# the DOM looks like a tree with several branches, and each box in the tree is called a node (object)

# try typing (accessing HTML through JS)
console.dir(document.body)     -> gives full detail about body ( list nodes, siblings etc)
console.log(document.body)     -> gives the body code of HTML file alone

# JS is used to dynamically manipulate the HTML,CSS of website based on user input
console.dir(document.body.childNodes[1]) -> gives div (body's 1st child)
document.body.style.background="green"; -> changes background color dynamically but vanishes when reloaded
document.body.childNodes[3].innerText="abcd" -> if the 3rd child of body was a h1 or p tag, then it changes the text

# NOTE: <script src="./index.js"></script> tag should be kept at last inside <body> tag
# if it is under <head> tag then we cant access body using DOMs (because script is loaded before body)

# selecting with id -> document.getElementById("myid")
# selecting with class -> document.getElementsByClassName("myclass")       (if you are typing these in console, it would return a HTMLcollection or array. so to style them we use array indexing to specify)
# selecting with tag -> document.getElementsByTagName("p")

let x= document.getElementsByClassName("myclass") -> console.dir(x) returns a HTML collection
document.querySelector("id/class/tag") -> returns first element encountered
document.querySelectorAll("class/tag") -> returns a node list having the same class/tag
document.querySelector(#list a / li a / .list a / #list .class a) -> multiple specifications allowed

# NOTE: type .class inside querySelector/SelectorAll
#       id selector cant come inside selectorAll since an Id is unique to an element

# querySelector is recomended since we can access the elements by multiple specifications

# tagName: returns tag for element nodes
# innerText: returns the text content of the element and all its children
# innerHTML: returns the plain text or HTML contents in the element
# textContent: returns textual content even for hidden elements -> similar to innerText but one difference it can be used on elements to display the text content with style="visibility:hidden" while innerText on such elements gives you empty strings

# there are 3 nodes under DOM -text nodes, comment nodes, element nodes
# we will mostly be working on element nodes

# Attributes
# getAttribute(attr) -> to get the attribute value
# setAttribute(attr, value) -> to set the attribute value

# Style
# node.style

#  CSS                   JS
#  color                color
#  background-color     backgroundColor             (all CSS properties are Camel-cases in JS)
#  font-size            fontSize                     Camel case is a way of writing phrases without spaces or punctuation. It involves capitalizing the first letter of each word, except for the first letter of the entire compound word

# adding new elements using JS
# insert elements
let el=document.createElement("div")
node.append(el) -> adds at the end of node(inside)
node.prepend(el) -> adds at the start of node(inside)
node.before(el) -> adds before the node(outside)
node.after(el) -> adds after the node(outside)

# delete element
node.remove() -> removes the node

# for eg:let say there is a blue box div and it has a class="box"
# if we want to add a button inside the div(blue box) without HTML:
let newBtn=document.createElement("button");
newBtn.innerText="click me";
document.querySelector(".box").prepend(newBtn);

# Element.classList is a collection of the class attributes of the element
div.classList.remove("foo") -> to remove classess
div.classList.add("anotherclass") -> to add classess
div.classList.toggle("class") -> if present then removes, if not present then adds it(toggling)

# every programmer keeps all the style in CSS only. so when a user clicks a button, then a new class is added to the element which already has a predefined styling inside CSS only
# NOTE: setAttrbute function erases old class and replaces it with new class, while classList.add method adds the class along with old class(so the element retains property of both classes)

# %%
# EVENTS
# The change in the state of an object is known as an Event
# Events are fired to notify code of "interesting changes" that may affect code execution.

# Mouse events(click, double click etc)
# Keyboard events (keypress, keyup, keydown)        -> keyboard and mouse events are most common
# Form events (submit etc.)
# Print event and many more

# inline method
<button onclick="console.log('button was clicked'); alert('hello')">click me</button> # single click
<button ondblclick="console.log('button was clicked');">click me 2 times</button> # double click

# if you want to print when mouse hovers over button
<button onmouseover="console.log('button was clicked'); alert('hello')">click me</button>

# external method
<button id="btn">click me</button>   # index.html

let btn1=document.querySelector("#btn");   # index.js
btn1.onclick =() =>{
    console.log("button was clicked");
}

# NOTE: external > inline -> event handling priority

# Event objects
it is a special object that has details about the event
all event handlers have acccess to the event object's properties and methods.

node.event = (e) =>{
    //handle here;              -> here "e" becomes the event object
}

e.target -> denotes the place where the event happened
e.type -> denotes the type of event (mouseclick, onclick, dblclick)
e.clientX, e.clientY -> denotes the position of x and y on screen
# eventobject.target, eventobject.type are more common

# Event Listeners
# event listeners are functions that wait for a specific event to occur on a particular HTML element, and then execute a designated piece of code in response to that event.
# callbacks are functions that are passed as arguements to other functions
# so when event occurs, callback gets executed
node.addEventListener(event,callback)
node.removeEventListener(event,callback)
# NOTE: the callback reference should be same to remove

# %%
# CLASSES AND OBJECTS

# prototype in JS:
# A javaScript object is an entity having state and behaviour(properties and method).
# JS objects have a special property called prototype
# We can set prototype using __proto__
# *if object and prototype have same method, object's moethod will be used.

# eg of an object:
# const student={
#     fullName: "tom",
#     marks:94.4,
#     printMarks:function(){
#         console.log("marks= ",this.marks);  -> this operator refers to the mark defined inside student
#     }
# }

# to access:
# student.fullName -> tom
# student.marks -> 94.4
# student.printMarks -> marks = 94.4

# NOTE: let arr=["apple","mango"];
# typeof arr -> object (because along with array, it has array prototype which has inbuilt functions like concat,push,pop etc)
# every object has a default set of methods inherited from prototype

# const employee={
#     calctax(){
#         console.log("tax is 10%");
#     }                                                   both notations are correct in defining a function
#     calctax2: function(){
#         console.log("tax is 10%");
#     }
# }

const emp={
    calctax(){
        console.log("tax is 10%");
    }
};

const karanarjun={
    salary: 5000,
};

karanarjun.__proto__=emp;            -> enables one function to enable the methods of other function
karan.calctax();                     -> valid since we have inherited the method from emp

# CLASSES
# class is a program-code template for creating objects
# those objects will have some state(variables) & some behaviour(functions) inside it

class Myclass{
    constructor(){...}
    myMethod(){...}
}

let myobj = new myclass();

Inheritance in JS
inheritance is passing down properties and methods from parent class to child class

class parent{
}

class child extends parent{
}

NOTE: if child and parent have same method, child's method will be used [method overriding]

# Super keyword

The super keyword is used to call the constructor of its parent class to access the parent's properties and methods

super(args) // call parent's constructor
super.parentMethod(args)

# %%
What is an API? - application programming interface
API's bridges communication between different piece of software
RESTful API is one of the most popular API's for web development. it is a set of rules which follow HTTP protocol(GET,POST etc)
baseurl/endpoint?query=value&query2=value
JSON - java script object notation

to convert JS object to JSON
const jsonData=JSON.stringify(data); where data->JS object
